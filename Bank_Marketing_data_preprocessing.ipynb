# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('bank-additional-full.csv',sep=';')
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns=None
plt.rcParams['figure.figsize']=(8,6)

# %%
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon       261         1    999         0
# 1      telephone   may         mon       149         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994          -36.4      4.857
# 1      nonexistent           1.1          93.994          -36.4      4.857
# 2      nonexistent           1.1          93.994          -36.4      4.857
# 3      nonexistent           1.1          93.994          -36.4      4.857
# 4      nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent          -1.1          94.767          -50.8      1.028
# 41184  nonexistent          -1.1          94.767          -50.8      1.028
# 41185  nonexistent          -1.1          94.767          -50.8      1.028
# 41186  nonexistent          -1.1          94.767          -50.8      1.028
# 41187      failure          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
data.shape
# Out:
# (41188, 21)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# Eliminating unwanted features:

# %% [markdown]
# 'Default'

# %%
pd.crosstab(data['y'],data['default'])
#as we can see there are only 3 customers in the default column who are not defaulters who have subscribed to the term deposit,
# rest all have said no to the term deposit.So we drop this column.
#this column will not be useful for analysis
# Out:
# default     no  unknown  yes
# y
# no       28391     8154    3
# yes       4197      443    0

# %%
pd.crosstab(data['y'],data['default']).T.plot(kind='bar')
plt.title('Distribution of Default', fontsize = 15)
plt.xticks(rotation = 'vertical', fontsize = 15)
plt.show()

# %%
data.drop(columns=['default'],axis=1,inplace=True)

# %% [markdown]
# 'Contact'

# %%
pd.crosstab(data.contact,data['y'],normalize=True)
# Out:
# y                no       yes
# contact
# cellular   0.541201  0.093547
# telephone  0.346145  0.019108

# %%
data.contact.value_counts().plot(kind='bar')
plt.title('Distribution of Contact', fontsize = 15)
plt.xticks(rotation = 'vertical', fontsize = 15)
plt.show()

# %%
pd.crosstab(data.contact,data['y'],normalize='index').plot(kind='bar')
plt.title('Distribution of Contact', fontsize = 15)
plt.xticks(rotation = 'vertical', fontsize = 15)
plt.show()
#from the graph both modes of contact are offering same percentage of conversions hence we can drop this column.

# %%
data.drop(['contact'],axis=True,inplace=True)

# %% [markdown]
# 'Duration'

# %%
data.duration.unique()
# Out:
# array([ 261,  149,  226, ..., 1246, 1556, 1868], dtype=int64)

# %%
#this attribute highly affects the output target (e.g., if duration=0 then y='no').
#the duration is not known before a call is performed. Also, after the end of the call y is obviously known.
#Thus, this input should only be included for benchmark purposes and should be discarded
#since our the intention is to have a realistic predictive model.

# %%
data.drop(['duration'],axis=1,inplace=True)

# %% [markdown]
# 'pdays'

# %%
data['pdays'].unique()
# Out:
# array([999,   6,   4,   3,   5,   1,   0,  10,   7,   8,   9,  11,   2,
#         12,  13,  14,  15,  16,  21,  17,  18,  22,  25,  26,  19,  27,
#         20], dtype=int64)

# %%
data['previous_campaign_contacted']=data['pdays'].apply(lambda x:'no' if x==999 else 'yes' )
#since there are many rows where the customer hasnt been contacted,
#hence we are converting it into a categrical binary column to chec k ehther they are contacted or not.

# %%
data['previous_campaign_contacted'].value_counts()
# Out:
# no     39673
# yes     1515
# Name: previous_campaign_contacted, dtype: int64

# %%
data=data.drop('pdays',1)

# %% [markdown]
# Typecasting the features:

# %% [markdown]
# 'previous'

# %%
data['previous'].value_counts()
# Out:
# 0    35563
# 1     4561
# 2      754
# 3      216
# 4       70
# 5       18
# 6        5
# 7        1
# Name: previous, dtype: int64

# %%
data['previous']=data['previous'].astype(object)

# %% [markdown]
# Since there are only 7 categories in the 'previous' column, we treat it as a categorical variable.

# %%
data.head()
# Out:
#    age        job  marital    education housing loan month day_of_week  \
# 0   56  housemaid  married     basic.4y      no   no   may         mon
# 1   57   services  married  high.school      no   no   may         mon
# 2   37   services  married  high.school     yes   no   may         mon
# 3   40     admin.  married     basic.6y      no   no   may         mon
# 4   56   services  married  high.school      no  yes   may         mon
#
#    campaign previous     poutcome  emp.var.rate  cons.price.idx  \
# 0         1        0  nonexistent           1.1          93.994
# 1         1        0  nonexistent           1.1          93.994
# 2         1        0  nonexistent           1.1          93.994
# 3         1        0  nonexistent           1.1          93.994
# 4         1        0  nonexistent           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed   y previous_campaign_contacted
# 0          -36.4      4.857       5191.0  no                          no
# 1          -36.4      4.857       5191.0  no                          no
# 2          -36.4      4.857       5191.0  no                          no
# 3          -36.4      4.857       5191.0  no                          no
# 4          -36.4      4.857       5191.0  no                          no

# %%
data.dtypes
# Out:
# age                              int64
# job                             object
# marital                         object
# education                       object
# housing                         object
# loan                            object
# month                           object
# day_of_week                     object
# campaign                         int64
# previous                        object
# poutcome                        object
# emp.var.rate                   float64
# cons.price.idx                 float64
# cons.conf.idx                  float64
# euribor3m                      float64
# nr.employed                    float64
# y                               object
# previous_campaign_contacted     object
# dtype: object

# %% [markdown]
# Splitting the data into numerical and categorical:

# %%
num_data = data.select_dtypes(include = np.number)
num_data
# Out:
#        age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0       56         1           1.1          93.994          -36.4      4.857
# 1       57         1           1.1          93.994          -36.4      4.857
# 2       37         1           1.1          93.994          -36.4      4.857
# 3       40         1           1.1          93.994          -36.4      4.857
# 4       56         1           1.1          93.994          -36.4      4.857
# ...    ...       ...           ...             ...            ...        ...
# 41183   73         1          -1.1          94.767          -50.8      1.028
# 41184   46         1          -1.1          94.767          -50.8      1.028
# 41185   56         2          -1.1          94.767          -50.8      1.028
# 41186   44         1          -1.1          94.767          -50.8      1.028
# 41187   74         3          -1.1          94.767          -50.8      1.028
#
#        nr.employed
# 0           5191.0
# 1           5191.0
# 2           5191.0
# 3           5191.0
# 4           5191.0
# ...            ...
# 41183       4963.6
# 41184       4963.6
# 41185       4963.6
# 41186       4963.6
# 41187       4963.6
#
# [41188 rows x 7 columns]

# %%
num_data.shape
# Out:
# (41188, 7)

# %%
cat_data=data.select_dtypes(exclude=np.number)
cat_data
# Out:
#                job  marital            education housing loan month  \
# 0        housemaid  married             basic.4y      no   no   may
# 1         services  married          high.school      no   no   may
# 2         services  married          high.school     yes   no   may
# 3           admin.  married             basic.6y      no   no   may
# 4         services  married          high.school      no  yes   may
# ...            ...      ...                  ...     ...  ...   ...
# 41183      retired  married  professional.course     yes   no   nov
# 41184  blue-collar  married  professional.course      no   no   nov
# 41185      retired  married    university.degree     yes   no   nov
# 41186   technician  married  professional.course      no   no   nov
# 41187      retired  married  professional.course     yes   no   nov
#
#       day_of_week previous     poutcome    y previous_campaign_contacted
# 0             mon        0  nonexistent   no                          no
# 1             mon        0  nonexistent   no                          no
# 2             mon        0  nonexistent   no                          no
# 3             mon        0  nonexistent   no                          no
# 4             mon        0  nonexistent   no                          no
# ...           ...      ...          ...  ...                         ...
# 41183         fri        0  nonexistent  yes                          no
# 41184         fri        0  nonexistent   no                          no
# 41185         fri        0  nonexistent   no                          no
# 41186         fri        0  nonexistent  yes                          no
# 41187         fri        1      failure   no                          no
#
# [41188 rows x 11 columns]

# %%
cat_data.shape
# Out:
# (41188, 11)

# %% [markdown]
# Checking the skewness in the numerical data:

# %%
num_data.skew()
# Out:
# age               0.784697
# campaign          4.762507
# emp.var.rate     -0.724096
# cons.price.idx   -0.230888
# cons.conf.idx     0.303180
# euribor3m        -0.709188
# nr.employed      -1.044262
# dtype: float64

# %%
num_columns = num_data.columns

fig,ax=plt.subplots(2,4,figsize=(20,10))
for i,subplot in zip(num_columns,ax.flatten()):
    sns.distplot(num_data[i],ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# Transforming the Numerical Data

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
num_data=pd.DataFrame(pt.fit_transform(num_data),columns=num_data.columns)
num_data
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.421949 -1.074734      0.418242        0.694015       0.913619
# 1      1.485905 -1.074734      0.418242        0.694015       0.913619
# 2     -0.152846 -1.074734      0.418242        0.694015       0.913619
# 3      0.155406 -1.074734      0.418242        0.694015       0.913619
# 4      1.421949 -1.074734      0.418242        0.694015       0.913619
# ...         ...       ...           ...             ...            ...
# 41183  2.353758 -1.074734     -1.078338        2.340762      -2.556729
# 41184  0.693550 -1.074734     -1.078338        2.340762      -2.556729
# 41185  1.421949  0.333407     -1.078338        2.340762      -2.556729
# 41186  0.524324 -1.074734     -1.078338        2.340762      -2.556729
# 41187  2.400102  0.877625     -1.078338        2.340762      -2.556729
#
#        euribor3m  nr.employed
# 0       0.680427    -0.095267
# 1       0.680427    -0.095267
# 2       0.680427    -0.095267
# 3       0.680427    -0.095267
# 4       0.680427    -0.095267
# ...          ...          ...
# 41183  -1.369267    -1.599452
# 41184  -1.369267    -1.599452
# 41185  -1.369267    -1.599452
# 41186  -1.369267    -1.599452
# 41187  -1.369267    -1.599452
#
# [41188 rows x 7 columns]

# %%
num_data.shape
# Out:
# (41188, 7)

# %%
num_data.skew()
# Out:
# age              -0.015488
# campaign          0.123735
# emp.var.rate     -0.266444
# cons.price.idx    0.006542
# cons.conf.idx    -0.011913
# euribor3m        -0.491038
# nr.employed      -0.178462
# dtype: float64

# %%
num_columns = num_data.columns

fig,ax=plt.subplots(2,4,figsize=(20,10))
for i,subplot in zip(num_columns,ax.flatten()):
    sns.distplot(num_data[i],ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# Treating the Outliers

# %%
data = pd.concat([num_data,cat_data],axis=1)
data
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.421949 -1.074734      0.418242        0.694015       0.913619
# 1      1.485905 -1.074734      0.418242        0.694015       0.913619
# 2     -0.152846 -1.074734      0.418242        0.694015       0.913619
# 3      0.155406 -1.074734      0.418242        0.694015       0.913619
# 4      1.421949 -1.074734      0.418242        0.694015       0.913619
# ...         ...       ...           ...             ...            ...
# 41183  2.353758 -1.074734     -1.078338        2.340762      -2.556729
# 41184  0.693550 -1.074734     -1.078338        2.340762      -2.556729
# 41185  1.421949  0.333407     -1.078338        2.340762      -2.556729
# 41186  0.524324 -1.074734     -1.078338        2.340762      -2.556729
# 41187  2.400102  0.877625     -1.078338        2.340762      -2.556729
#
#        euribor3m  nr.employed          job  marital            education  \
# 0       0.680427    -0.095267    housemaid  married             basic.4y
# 1       0.680427    -0.095267     services  married          high.school
# 2       0.680427    -0.095267     services  married          high.school
# 3       0.680427    -0.095267       admin.  married             basic.6y
# 4       0.680427    -0.095267     services  married          high.school
# ...          ...          ...          ...      ...                  ...
# 41183  -1.369267    -1.599452      retired  married  professional.course
# 41184  -1.369267    -1.599452  blue-collar  married  professional.course
# 41185  -1.369267    -1.599452      retired  married    university.degree
# 41186  -1.369267    -1.599452   technician  married  professional.course
# 41187  -1.369267    -1.599452      retired  married  professional.course
#
#       housing loan month day_of_week previous     poutcome    y  \
# 0          no   no   may         mon        0  nonexistent   no
# 1          no   no   may         mon        0  nonexistent   no
# 2         yes   no   may         mon        0  nonexistent   no
# 3          no   no   may         mon        0  nonexistent   no
# 4          no  yes   may         mon        0  nonexistent   no
# ...       ...  ...   ...         ...      ...          ...  ...
# 41183     yes   no   nov         fri        0  nonexistent  yes
# 41184      no   no   nov         fri        0  nonexistent   no
# 41185     yes   no   nov         fri        0  nonexistent   no
# 41186      no   no   nov         fri        0  nonexistent  yes
# 41187     yes   no   nov         fri        1      failure   no
#
#       previous_campaign_contacted
# 0                              no
# 1                              no
# 2                              no
# 3                              no
# 4                              no
# ...                           ...
# 41183                          no
# 41184                          no
# 41185                          no
# 41186                          no
# 41187                          no
#
# [41188 rows x 18 columns]

# %%
data.shape
# Out:
# (41188, 18)

# %%
data.boxplot()
plt.show()

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
ub=Q3+(1.5*IQR)
lb=Q1-(1.5*IQR)
data=data[~(((data<lb)| (data>ub)).any(axis=1))]

# %%
data.reset_index(drop=True,inplace=True)

# %%
# data.drop(['level_0','index'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (41019, 18)

# %% [markdown]
# Since the shape of the data has been changed from (41188, 18) to (41019, 18) we can infer that there are 169 outliers which have
# been dropped.

# %%
data.boxplot()
plt.show()

# %% [markdown]
# Splitting the data again after removing the Outliers:

# %%
num_data=data.select_dtypes(include=np.number)
num_data
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.421949 -1.074734      0.418242        0.694015       0.913619
# 1      1.485905 -1.074734      0.418242        0.694015       0.913619
# 2     -0.152846 -1.074734      0.418242        0.694015       0.913619
# 3      0.155406 -1.074734      0.418242        0.694015       0.913619
# 4      1.421949 -1.074734      0.418242        0.694015       0.913619
# ...         ...       ...           ...             ...            ...
# 41014 -1.457233 -1.074734     -1.078338        1.961396      -2.184275
# 41015  1.669813  0.333407     -1.078338        1.961396      -2.184275
# 41016 -1.010942 -1.074734     -1.078338        1.961396      -2.184275
# 41017  1.952595 -1.074734     -1.078338        1.961396      -2.184275
# 41018  0.345314 -1.074734     -1.078338        1.961396      -2.184275
#
#        euribor3m  nr.employed
# 0       0.680427    -0.095267
# 1       0.680427    -0.095267
# 2       0.680427    -0.095267
# 3       0.680427    -0.095267
# 4       0.680427    -0.095267
# ...          ...          ...
# 41014  -1.367771    -1.599452
# 41015  -1.367771    -1.599452
# 41016  -1.367771    -1.599452
# 41017  -1.367771    -1.599452
# 41018  -1.367571    -1.599452
#
# [41019 rows x 7 columns]

# %%
cat_data=data.select_dtypes(exclude=np.number)

# %%
cat_data
# Out:
#               job  marital            education housing loan month  \
# 0       housemaid  married             basic.4y      no   no   may
# 1        services  married          high.school      no   no   may
# 2        services  married          high.school     yes   no   may
# 3          admin.  married             basic.6y      no   no   may
# 4        services  married          high.school      no  yes   may
# ...           ...      ...                  ...     ...  ...   ...
# 41014  technician   single    university.degree     yes   no   oct
# 41015     retired  married  professional.course      no  yes   oct
# 41016  management  married    university.degree      no  yes   oct
# 41017     retired  married             basic.4y     yes   no   oct
# 41018    services  married             basic.9y      no   no   oct
#
#       day_of_week previous     poutcome    y previous_campaign_contacted
# 0             mon        0  nonexistent   no                          no
# 1             mon        0  nonexistent   no                          no
# 2             mon        0  nonexistent   no                          no
# 3             mon        0  nonexistent   no                          no
# 4             mon        0  nonexistent   no                          no
# ...           ...      ...          ...  ...                         ...
# 41014         wed        1      failure  yes                          no
# 41015         wed        1      failure   no                          no
# 41016         wed        1      success  yes                         yes
# 41017         wed        3      success  yes                         yes
# 41018         thu        0  nonexistent   no                          no
#
# [41019 rows x 11 columns]

# %% [markdown]
# Scaling the Numerical Data

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
num_data_scaled=pd.DataFrame(ss.fit_transform(num_data),columns=num_data.columns)

# %%
num_data
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.421949 -1.074734      0.418242        0.694015       0.913619
# 1      1.485905 -1.074734      0.418242        0.694015       0.913619
# 2     -0.152846 -1.074734      0.418242        0.694015       0.913619
# 3      0.155406 -1.074734      0.418242        0.694015       0.913619
# 4      1.421949 -1.074734      0.418242        0.694015       0.913619
# ...         ...       ...           ...             ...            ...
# 41014 -1.457233 -1.074734     -1.078338        1.961396      -2.184275
# 41015  1.669813  0.333407     -1.078338        1.961396      -2.184275
# 41016 -1.010942 -1.074734     -1.078338        1.961396      -2.184275
# 41017  1.952595 -1.074734     -1.078338        1.961396      -2.184275
# 41018  0.345314 -1.074734     -1.078338        1.961396      -2.184275
#
#        euribor3m  nr.employed
# 0       0.680427    -0.095267
# 1       0.680427    -0.095267
# 2       0.680427    -0.095267
# 3       0.680427    -0.095267
# 4       0.680427    -0.095267
# ...          ...          ...
# 41014  -1.367771    -1.599452
# 41015  -1.367771    -1.599452
# 41016  -1.367771    -1.599452
# 41017  -1.367771    -1.599452
# 41018  -1.367571    -1.599452
#
# [41019 rows x 7 columns]

# %%
num_data_scaled
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.428160 -1.075554      0.413830        0.705707       0.915275
# 1      1.492468 -1.075554      0.413830        0.705707       0.915275
# 2     -0.155321 -1.075554      0.413830        0.705707       0.915275
# 3      0.154631 -1.075554      0.413830        0.705707       0.915275
# 4      1.428160 -1.075554      0.413830        0.705707       0.915275
# ...         ...       ...           ...             ...            ...
# 41014 -1.466903 -1.075554     -1.083694        1.982796      -2.212450
# 41015  1.677390  0.332038     -1.083694        1.982796      -2.212450
# 41016 -1.018150 -1.075554     -1.083694        1.982796      -2.212450
# 41017  1.961733 -1.075554     -1.083694        1.982796      -2.212450
# 41018  0.345586 -1.075554     -1.083694        1.982796      -2.212450
#
#        euribor3m  nr.employed
# 0       0.676028    -0.101940
# 1       0.676028    -0.101940
# 2       0.676028    -0.101940
# 3       0.676028    -0.101940
# 4       0.676028    -0.101940
# ...          ...          ...
# 41014  -1.375879    -1.610565
# 41015  -1.375879    -1.610565
# 41016  -1.375879    -1.610565
# 41017  -1.375879    -1.610565
# 41018  -1.375678    -1.610565
#
# [41019 rows x 7 columns]

# %% [markdown]
# Checking the Multicollinearity in the numerical data:

# %%
sns.heatmap(num_data_scaled.corr(),annot=True)

# %%
num_data.columns
# Out:
# Index(['age', 'campaign', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed'],
#       dtype='object')

# %% [markdown]
# The columns: 'emp.var.rate', 'cons.price.idx', 'euribor3m', 'nr.employed' are showing multicoliinearity.

# %% [markdown]
# Data Pre-Processing of the Categorical Data:

# %%
cat_data
# Out:
#               job  marital            education housing loan month  \
# 0       housemaid  married             basic.4y      no   no   may
# 1        services  married          high.school      no   no   may
# 2        services  married          high.school     yes   no   may
# 3          admin.  married             basic.6y      no   no   may
# 4        services  married          high.school      no  yes   may
# ...           ...      ...                  ...     ...  ...   ...
# 41014  technician   single    university.degree     yes   no   oct
# 41015     retired  married  professional.course      no  yes   oct
# 41016  management  married    university.degree      no  yes   oct
# 41017     retired  married             basic.4y     yes   no   oct
# 41018    services  married             basic.9y      no   no   oct
#
#       day_of_week previous     poutcome    y previous_campaign_contacted
# 0             mon        0  nonexistent   no                          no
# 1             mon        0  nonexistent   no                          no
# 2             mon        0  nonexistent   no                          no
# 3             mon        0  nonexistent   no                          no
# 4             mon        0  nonexistent   no                          no
# ...           ...      ...          ...  ...                         ...
# 41014         wed        1      failure  yes                          no
# 41015         wed        1      failure   no                          no
# 41016         wed        1      success  yes                         yes
# 41017         wed        3      success  yes                         yes
# 41018         thu        0  nonexistent   no                          no
#
# [41019 rows x 11 columns]

# %% [markdown]
# Treating Unknown Values in the categorical data

# %%
cat_data.replace({'unknown':np.nan},inplace=True)
cat_data
# Out:
#               job  marital            education housing loan month  \
# 0       housemaid  married             basic.4y      no   no   may
# 1        services  married          high.school      no   no   may
# 2        services  married          high.school     yes   no   may
# 3          admin.  married             basic.6y      no   no   may
# 4        services  married          high.school      no  yes   may
# ...           ...      ...                  ...     ...  ...   ...
# 41014  technician   single    university.degree     yes   no   oct
# 41015     retired  married  professional.course      no  yes   oct
# 41016  management  married    university.degree      no  yes   oct
# 41017     retired  married             basic.4y     yes   no   oct
# 41018    services  married             basic.9y      no   no   oct
#
#       day_of_week  previous     poutcome    y previous_campaign_contacted
# 0             mon         0  nonexistent   no                          no
# 1             mon         0  nonexistent   no                          no
# 2             mon         0  nonexistent   no                          no
# 3             mon         0  nonexistent   no                          no
# 4             mon         0  nonexistent   no                          no
# ...           ...       ...          ...  ...                         ...
# 41014         wed         1      failure  yes                          no
# 41015         wed         1      failure   no                          no
# 41016         wed         1      success  yes                         yes
# 41017         wed         3      success  yes                         yes
# 41018         thu         0  nonexistent   no                          no
#
# [41019 rows x 11 columns]

# %%
cat_data.isnull().sum()
# Out:
# job                             329
# marital                          80
# education                      1702
# housing                         987
# loan                            987
# month                             0
# day_of_week                       0
# previous                          0
# poutcome                          0
# y                                 0
# previous_campaign_contacted       0
# dtype: int64

# %%
for i in cat_data.columns:
    print(cat_data[i].value_counts(dropna=False))
    print('*'*100)
# Out:
# admin.           10373
# blue-collar       9242
# technician        6719
# services          3962
# management        2919
# retired           1700
# entrepreneur      1455
# self-employed     1420
# housemaid         1055
# unemployed        1010
# student            835
# NaN                329
# Name: job, dtype: int64
# ****************************************************************************************************
# married     24851
# single      11494
# divorced     4594
# NaN            80
# Name: marital, dtype: int64
# ****************************************************************************************************
# university.degree      12116
# high.school             9483
# basic.9y                6031
# professional.course     5219
# basic.4y                4164
# basic.6y                2286
# NaN                     1702
# illiterate                18
# Name: education, dtype: int64
# ****************************************************************************************************
# yes    21472
# no     18560
# NaN      987
# Name: housing, dtype: int64
# ****************************************************************************************************
# no     33805
# yes     6227
# NaN      987
# Name: loan, dtype: int64
# ****************************************************************************************************
# may    13761
# jul     7174
# aug     6167
# jun     5317
# nov     3970
# apr     2630
# oct      714
# sep      563
# mar      544
# dec      179
# Name: month, dtype: int64
# ****************************************************************************************************
# thu    8594
# mon    8477
# wed    8104
# tue    8049
# fri    7795
# Name: day_of_week, dtype: int64
# ****************************************************************************************************
# 0    35494
# 1     4523
# 2      721
# 3      202
# 4       61
# 5       15
# 6        3
# Name: previous, dtype: int64
# ****************************************************************************************************
# nonexistent    35494
# failure         4204
# success         1321
# Name: poutcome, dtype: int64
# ****************************************************************************************************
# no     36455
# yes     4564
# Name: y, dtype: int64
# ****************************************************************************************************
# no     39563
# yes     1456
# Name: previous_campaign_contacted, dtype: int64
# ****************************************************************************************************

# %%
cat_data['job'].value_counts(dropna=False, normalize=True)*100
# Out:
# admin.           25.288281
# blue-collar      22.531022
# technician       16.380214
# services          9.658939
# management        7.116214
# retired           4.144421
# entrepreneur      3.547137
# self-employed     3.461810
# housemaid         2.571979
# unemployed        2.462274
# student           2.035642
# NaN               0.802067
# Name: job, dtype: float64

# %% [markdown]
# There are 0.8% NaN values in the job column.

# %% [markdown]
# 'marital'

# %%
cat_data['marital'].value_counts(dropna=False, normalize=True)*100
# Out:
# married     60.584120
# single      28.021161
# divorced    11.199688
# NaN          0.195032
# Name: marital, dtype: float64

# %%
data.groupby('marital')['age'].mean()
# Out:
# marital
# divorced    0.474967
# married     0.241511
# single     -0.706347
# unknown     0.019292
# Name: age, dtype: float64

# %% [markdown]
# Since the average age of the married and divorced people is almost same so we cannot estimate the marital status of unknowns
# through the 'age' variable alone.

# %%
cat_data['education'].value_counts(dropna=False,normalize=True)*100
# Out:
# university.degree      29.537531
# high.school            23.118555
# basic.9y               14.702943
# professional.course    12.723372
# basic.4y               10.151393
# basic.6y                5.573027
# NaN                     4.149297
# illiterate              0.043882
# Name: education, dtype: float64

# %% [markdown]
# There are 4% nan values in this column

# %% [markdown]
# 'housing'

# %%
cat_data['housing'].value_counts(dropna=False,normalize=True)*100
# Out:
# yes    52.346474
# no     45.247324
# NaN     2.406202
# Name: housing, dtype: float64

# %% [markdown]
# 'loan'

# %%
cat_data['loan'].value_counts(dropna=False,normalize=True)*100
# Out:
# no     82.413028
# yes    15.180770
# NaN     2.406202
# Name: loan, dtype: float64

# %% [markdown]
# As we can see that the number of null values in both the features 'housing' and 'loan' are the same, it is possible that
# they have null values in the same record.

# %%
num_data_scaled.shape
# Out:
# (41019, 7)

# %%
cat_data.shape
# Out:
# (41019, 11)

# %%
data = pd.concat([num_data_scaled,cat_data],axis=1)

# %%
data.shape
# Out:
# (41019, 18)

# %%
data=data.dropna(subset=['housing'],axis=0)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.428160 -1.075554      0.413830        0.705707       0.915275
# 1      1.492468 -1.075554      0.413830        0.705707       0.915275
# 2     -0.155321 -1.075554      0.413830        0.705707       0.915275
# 3      0.154631 -1.075554      0.413830        0.705707       0.915275
# 4      1.428160 -1.075554      0.413830        0.705707       0.915275
# ...         ...       ...           ...             ...            ...
# 40027 -1.466903 -1.075554     -1.083694        1.982796      -2.212450
# 40028  1.677390  0.332038     -1.083694        1.982796      -2.212450
# 40029 -1.018150 -1.075554     -1.083694        1.982796      -2.212450
# 40030  1.961733 -1.075554     -1.083694        1.982796      -2.212450
# 40031  0.345586 -1.075554     -1.083694        1.982796      -2.212450
#
#        euribor3m  nr.employed         job  marital            education  \
# 0       0.676028    -0.101940   housemaid  married             basic.4y
# 1       0.676028    -0.101940    services  married          high.school
# 2       0.676028    -0.101940    services  married          high.school
# 3       0.676028    -0.101940      admin.  married             basic.6y
# 4       0.676028    -0.101940    services  married          high.school
# ...          ...          ...         ...      ...                  ...
# 40027  -1.375879    -1.610565  technician   single    university.degree
# 40028  -1.375879    -1.610565     retired  married  professional.course
# 40029  -1.375879    -1.610565  management  married    university.degree
# 40030  -1.375879    -1.610565     retired  married             basic.4y
# 40031  -1.375678    -1.610565    services  married             basic.9y
#
#       housing loan month day_of_week  previous     poutcome    y  \
# 0          no   no   may         mon         0  nonexistent   no
# 1          no   no   may         mon         0  nonexistent   no
# 2         yes   no   may         mon         0  nonexistent   no
# 3          no   no   may         mon         0  nonexistent   no
# 4          no  yes   may         mon         0  nonexistent   no
# ...       ...  ...   ...         ...       ...          ...  ...
# 40027     yes   no   oct         wed         1      failure  yes
# 40028      no  yes   oct         wed         1      failure   no
# 40029      no  yes   oct         wed         1      success  yes
# 40030     yes   no   oct         wed         3      success  yes
# 40031      no   no   oct         thu         0  nonexistent   no
#
#       previous_campaign_contacted
# 0                              no
# 1                              no
# 2                              no
# 3                              no
# 4                              no
# ...                           ...
# 40027                          no
# 40028                          no
# 40029                         yes
# 40030                         yes
# 40031                          no
#
# [40032 rows x 18 columns]

# %%
data.isna().sum()
# Out:
# age                               0
# campaign                          0
# emp.var.rate                      0
# cons.price.idx                    0
# cons.conf.idx                     0
# euribor3m                         0
# nr.employed                       0
# job                             324
# marital                          79
# education                      1663
# housing                           0
# loan                              0
# month                             0
# day_of_week                       0
# previous                          0
# poutcome                          0
# y                                 0
# previous_campaign_contacted       0
# dtype: int64

# %% [markdown]
# As we can infer from the above output that after dropping the null values in the 'housing' column alone the null values in the
# 'loan' column are also dropped. Hence, we conclude that the rows in both the columns having null values are the same.

# %% [markdown]
# For the columns: 'job','marital','education' we will use knn imputer for null values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40032 entries, 0 to 40031
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          40032 non-null  float64
#  1   campaign                     40032 non-null  float64
#  2   emp.var.rate                 40032 non-null  float64
#  3   cons.price.idx               40032 non-null  float64
#  4   cons.conf.idx                40032 non-null  float64
#  5   euribor3m                    40032 non-null  float64
#  6   nr.employed                  40032 non-null  float64
#  7   job                          39708 non-null  object
#  8   marital                      39953 non-null  object
#  9   education                    38369 non-null  object
#  10  housing                      40032 non-null  object
#  11  loan                         40032 non-null  object
#  12  month                        40032 non-null  object
#  13  day_of_week                  40032 non-null  object
#  14  previous                     40032 non-null  int64
#  15  poutcome                     40032 non-null  object
#  16  y                            40032 non-null  object
#  17  previous_campaign_contacted  40032 non-null  object
# dtypes: float64(7), int64(1), object(10)
# memory usage: 5.5+ MB

# %% [markdown]
# Encoding the categorical data:

# %%
data.head()
# Out:
#         age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  1.428160 -1.075554       0.41383        0.705707       0.915275   0.676028
# 1  1.492468 -1.075554       0.41383        0.705707       0.915275   0.676028
# 2 -0.155321 -1.075554       0.41383        0.705707       0.915275   0.676028
# 3  0.154631 -1.075554       0.41383        0.705707       0.915275   0.676028
# 4  1.428160 -1.075554       0.41383        0.705707       0.915275   0.676028
#
#    nr.employed        job  marital    education housing loan month  \
# 0     -0.10194  housemaid  married     basic.4y      no   no   may
# 1     -0.10194   services  married  high.school      no   no   may
# 2     -0.10194   services  married  high.school     yes   no   may
# 3     -0.10194     admin.  married     basic.6y      no   no   may
# 4     -0.10194   services  married  high.school      no  yes   may
#
#   day_of_week  previous     poutcome   y previous_campaign_contacted
# 0         mon         0  nonexistent  no                          no
# 1         mon         0  nonexistent  no                          no
# 2         mon         0  nonexistent  no                          no
# 3         mon         0  nonexistent  no                          no
# 4         mon         0  nonexistent  no                          no

# %%
data.shape
# Out:
# (40032, 18)

# %%
data['previous']=data['previous'].astype(object)

# %%
num_data_final= data.select_dtypes(include=np.number)
num_data_final
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.428160 -1.075554      0.413830        0.705707       0.915275
# 1      1.492468 -1.075554      0.413830        0.705707       0.915275
# 2     -0.155321 -1.075554      0.413830        0.705707       0.915275
# 3      0.154631 -1.075554      0.413830        0.705707       0.915275
# 4      1.428160 -1.075554      0.413830        0.705707       0.915275
# ...         ...       ...           ...             ...            ...
# 40027 -1.466903 -1.075554     -1.083694        1.982796      -2.212450
# 40028  1.677390  0.332038     -1.083694        1.982796      -2.212450
# 40029 -1.018150 -1.075554     -1.083694        1.982796      -2.212450
# 40030  1.961733 -1.075554     -1.083694        1.982796      -2.212450
# 40031  0.345586 -1.075554     -1.083694        1.982796      -2.212450
#
#        euribor3m  nr.employed
# 0       0.676028    -0.101940
# 1       0.676028    -0.101940
# 2       0.676028    -0.101940
# 3       0.676028    -0.101940
# 4       0.676028    -0.101940
# ...          ...          ...
# 40027  -1.375879    -1.610565
# 40028  -1.375879    -1.610565
# 40029  -1.375879    -1.610565
# 40030  -1.375879    -1.610565
# 40031  -1.375678    -1.610565
#
# [40032 rows x 7 columns]

# %%
num_data_final.shape
# Out:
# (40032, 7)

# %%
cat_data=data.select_dtypes(exclude=np.number)
cat_data
# Out:
#               job  marital            education housing loan month  \
# 0       housemaid  married             basic.4y      no   no   may
# 1        services  married          high.school      no   no   may
# 2        services  married          high.school     yes   no   may
# 3          admin.  married             basic.6y      no   no   may
# 4        services  married          high.school      no  yes   may
# ...           ...      ...                  ...     ...  ...   ...
# 40027  technician   single    university.degree     yes   no   oct
# 40028     retired  married  professional.course      no  yes   oct
# 40029  management  married    university.degree      no  yes   oct
# 40030     retired  married             basic.4y     yes   no   oct
# 40031    services  married             basic.9y      no   no   oct
#
#       day_of_week previous     poutcome    y previous_campaign_contacted
# 0             mon        0  nonexistent   no                          no
# 1             mon        0  nonexistent   no                          no
# 2             mon        0  nonexistent   no                          no
# 3             mon        0  nonexistent   no                          no
# 4             mon        0  nonexistent   no                          no
# ...           ...      ...          ...  ...                         ...
# 40027         wed        1      failure  yes                          no
# 40028         wed        1      failure   no                          no
# 40029         wed        1      success  yes                         yes
# 40030         wed        3      success  yes                         yes
# 40031         thu        0  nonexistent   no                          no
#
# [40032 rows x 11 columns]

# %%
cat_data.shape
# Out:
# (40032, 11)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df=pd.DataFrame()
for i in ['housing', 'loan', 'month',
       'day_of_week', 'poutcome',
       'previous_campaign_contacted']:
    
    df[i]=le.fit_transform(cat_data[i].values)
df
# Out:
#        housing  loan  month  day_of_week  poutcome  \
# 0            0     0      6            1         1
# 1            0     0      6            1         1
# 2            1     0      6            1         1
# 3            0     0      6            1         1
# 4            0     1      6            1         1
# ...        ...   ...    ...          ...       ...
# 40027        1     0      8            4         0
# 40028        0     1      8            4         0
# 40029        0     1      8            4         2
# 40030        1     0      8            4         2
# 40031        0     0      8            2         1
#
#        previous_campaign_contacted
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# 40027                            0
# 40028                            0
# 40029                            1
# 40030                            1
# 40031                            0
#
# [40032 rows x 6 columns]

# %%
cat_data_encoded = df
cat_data_encoded
# Out:
#        housing  loan  month  day_of_week  poutcome  \
# 0            0     0      6            1         1
# 1            0     0      6            1         1
# 2            1     0      6            1         1
# 3            0     0      6            1         1
# 4            0     1      6            1         1
# ...        ...   ...    ...          ...       ...
# 40027        1     0      8            4         0
# 40028        0     1      8            4         0
# 40029        0     1      8            4         2
# 40030        1     0      8            4         2
# 40031        0     0      8            2         1
#
#        previous_campaign_contacted
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# 40027                            0
# 40028                            0
# 40029                            1
# 40030                            1
# 40031                            0
#
# [40032 rows x 6 columns]

# %% [markdown]
# Encoding the categorical variables with null values:

# %% [markdown]
# 'education'

# %%
cat_data['education']=cat_data['education'].replace({'basic.4y': 0,
 'high.school': 3,
 'basic.6y': 1,
 'basic.9y': 2,
 'professional.course': 5,
 'university.degree': 6,
'illiterate':4})

# %%
cat_data['education'].value_counts(dropna=False)
# Out:
# 6.0    11840
# 3.0     9263
# 2.0     5881
# 5.0     5094
# 0.0     4047
# 1.0     2226
# NaN     1663
# 4.0       18
# Name: education, dtype: int64

# %% [markdown]
# 'marital'

# %%
cat_data['marital']=cat_data['marital'].replace({'married': 1, 'single': 2, 'divorced': 0})

# %%
cat_data['marital'].value_counts(dropna=False)
# Out:
# 1.0    24263
# 2.0    11216
# 0.0     4474
# NaN       79
# Name: marital, dtype: int64

# %%
cat_data['job']=cat_data['job'].replace({'housemaid': 3,
 'services': 7,
 'admin.': 0,
 'blue-collar': 1,
 'technician': 9,
 'retired': 5,
 'management': 4,
 'unemployed': 10,
 'self-employed': 6,
 'entrepreneur': 2,
 'student':8})

# %%
cat_data['job'].value_counts(dropna=False)
# Out:
# 0.0     10146
# 1.0      9002
# 9.0      6572
# 7.0      3862
# 4.0      2848
# 5.0      1656
# 2.0      1419
# 6.0      1380
# 3.0      1026
# 10.0      983
# 8.0       814
# NaN       324
# Name: job, dtype: int64

# %%
cat_data_encoded['job']=cat_data['job']
cat_data_encoded
# Out:
#        housing  loan  month  day_of_week  poutcome  \
# 0            0     0      6            1         1
# 1            0     0      6            1         1
# 2            1     0      6            1         1
# 3            0     0      6            1         1
# 4            0     1      6            1         1
# ...        ...   ...    ...          ...       ...
# 40027        1     0      8            4         0
# 40028        0     1      8            4         0
# 40029        0     1      8            4         2
# 40030        1     0      8            4         2
# 40031        0     0      8            2         1
#
#        previous_campaign_contacted  job
# 0                                0  3.0
# 1                                0  7.0
# 2                                0  7.0
# 3                                0  0.0
# 4                                0  7.0
# ...                            ...  ...
# 40027                            0  9.0
# 40028                            0  5.0
# 40029                            1  4.0
# 40030                            1  5.0
# 40031                            0  7.0
#
# [40032 rows x 7 columns]

# %%
cat_data_encoded['marital']=cat_data['marital']
cat_data_encoded['education']=cat_data['education']

# %%
cat_data_encoded
# Out:
#        housing  loan  month  day_of_week  poutcome  \
# 0            0     0      6            1         1
# 1            0     0      6            1         1
# 2            1     0      6            1         1
# 3            0     0      6            1         1
# 4            0     1      6            1         1
# ...        ...   ...    ...          ...       ...
# 40027        1     0      8            4         0
# 40028        0     1      8            4         0
# 40029        0     1      8            4         2
# 40030        1     0      8            4         2
# 40031        0     0      8            2         1
#
#        previous_campaign_contacted  job  marital  education
# 0                                0  3.0      1.0        0.0
# 1                                0  7.0      1.0        3.0
# 2                                0  7.0      1.0        3.0
# 3                                0  0.0      1.0        1.0
# 4                                0  7.0      1.0        3.0
# ...                            ...  ...      ...        ...
# 40027                            0  9.0      2.0        6.0
# 40028                            0  5.0      1.0        5.0
# 40029                            1  4.0      1.0        6.0
# 40030                            1  5.0      1.0        0.0
# 40031                            0  7.0      1.0        2.0
#
# [40032 rows x 9 columns]

# %%
num_data_final
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.428160 -1.075554      0.413830        0.705707       0.915275
# 1      1.492468 -1.075554      0.413830        0.705707       0.915275
# 2     -0.155321 -1.075554      0.413830        0.705707       0.915275
# 3      0.154631 -1.075554      0.413830        0.705707       0.915275
# 4      1.428160 -1.075554      0.413830        0.705707       0.915275
# ...         ...       ...           ...             ...            ...
# 40027 -1.466903 -1.075554     -1.083694        1.982796      -2.212450
# 40028  1.677390  0.332038     -1.083694        1.982796      -2.212450
# 40029 -1.018150 -1.075554     -1.083694        1.982796      -2.212450
# 40030  1.961733 -1.075554     -1.083694        1.982796      -2.212450
# 40031  0.345586 -1.075554     -1.083694        1.982796      -2.212450
#
#        euribor3m  nr.employed
# 0       0.676028    -0.101940
# 1       0.676028    -0.101940
# 2       0.676028    -0.101940
# 3       0.676028    -0.101940
# 4       0.676028    -0.101940
# ...          ...          ...
# 40027  -1.375879    -1.610565
# 40028  -1.375879    -1.610565
# 40029  -1.375879    -1.610565
# 40030  -1.375879    -1.610565
# 40031  -1.375678    -1.610565
#
# [40032 rows x 7 columns]

# %%
num_data_final.shape
# Out:
# (40032, 7)

# %%
cat_data_encoded
# Out:
#        housing  loan  month  day_of_week  poutcome  \
# 0            0     0      6            1         1
# 1            0     0      6            1         1
# 2            1     0      6            1         1
# 3            0     0      6            1         1
# 4            0     1      6            1         1
# ...        ...   ...    ...          ...       ...
# 40027        1     0      8            4         0
# 40028        0     1      8            4         0
# 40029        0     1      8            4         2
# 40030        1     0      8            4         2
# 40031        0     0      8            2         1
#
#        previous_campaign_contacted  job  marital  education
# 0                                0  3.0      1.0        0.0
# 1                                0  7.0      1.0        3.0
# 2                                0  7.0      1.0        3.0
# 3                                0  0.0      1.0        1.0
# 4                                0  7.0      1.0        3.0
# ...                            ...  ...      ...        ...
# 40027                            0  9.0      2.0        6.0
# 40028                            0  5.0      1.0        5.0
# 40029                            1  4.0      1.0        6.0
# 40030                            1  5.0      1.0        0.0
# 40031                            0  7.0      1.0        2.0
#
# [40032 rows x 9 columns]

# %%
cat_data_encoded.shape
# Out:
# (40032, 9)

# %%
data_final = pd.concat([num_data_final,cat_data_encoded],axis=1)
data_final
# Out:
#             age  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0      1.428160 -1.075554      0.413830        0.705707       0.915275
# 1      1.492468 -1.075554      0.413830        0.705707       0.915275
# 2     -0.155321 -1.075554      0.413830        0.705707       0.915275
# 3      0.154631 -1.075554      0.413830        0.705707       0.915275
# 4      1.428160 -1.075554      0.413830        0.705707       0.915275
# ...         ...       ...           ...             ...            ...
# 40027 -1.466903 -1.075554     -1.083694        1.982796      -2.212450
# 40028  1.677390  0.332038     -1.083694        1.982796      -2.212450
# 40029 -1.018150 -1.075554     -1.083694        1.982796      -2.212450
# 40030  1.961733 -1.075554     -1.083694        1.982796      -2.212450
# 40031  0.345586 -1.075554     -1.083694        1.982796      -2.212450
#
#        euribor3m  nr.employed  housing  loan  month  day_of_week  poutcome  \
# 0       0.676028    -0.101940        0     0      6            1         1
# 1       0.676028    -0.101940        0     0      6            1         1
# 2       0.676028    -0.101940        1     0      6            1         1
# 3       0.676028    -0.101940        0     0      6            1         1
# 4       0.676028    -0.101940        0     1      6            1         1
# ...          ...          ...      ...   ...    ...          ...       ...
# 40027  -1.375879    -1.610565        1     0      8            4         0
# 40028  -1.375879    -1.610565        0     1      8            4         0
# 40029  -1.375879    -1.610565        0     1      8            4         2
# 40030  -1.375879    -1.610565        1     0      8            4         2
# 40031  -1.375678    -1.610565        0     0      8            2         1
#
#        previous_campaign_contacted  job  marital  education
# 0                                0  3.0      1.0        0.0
# 1                                0  7.0      1.0        3.0
# 2                                0  7.0      1.0        3.0
# 3                                0  0.0      1.0        1.0
# 4                                0  7.0      1.0        3.0
# ...                            ...  ...      ...        ...
# 40027                            0  9.0      2.0        6.0
# 40028                            0  5.0      1.0        5.0
# 40029                            1  4.0      1.0        6.0
# 40030                            1  5.0      1.0        0.0
# 40031                            0  7.0      1.0        2.0
#
# [40032 rows x 16 columns]

# %%
data_final.shape
# Out:
# (40032, 16)

# %%
data_final.columns
# Out:
# Index(['age', 'campaign', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'housing', 'loan', 'month', 'day_of_week',
#        'poutcome', 'previous_campaign_contacted', 'job', 'marital',
#        'education'],
#       dtype='object')

# %%
data_final.isna().sum()
# Out:
# age                               0
# campaign                          0
# emp.var.rate                      0
# cons.price.idx                    0
# cons.conf.idx                     0
# euribor3m                         0
# nr.employed                       0
# housing                           0
# loan                              0
# month                             0
# day_of_week                       0
# poutcome                          0
# previous_campaign_contacted       0
# job                             324
# marital                          79
# education                      1663
# dtype: int64

# %% [markdown]
# using knn imputer to fill the missing values in the final data:

# %%
from sklearn.impute import KNNImputer
knn=KNNImputer(n_neighbors=3)
data_final=pd.DataFrame(knn.fit_transform(data_final),columns=data_final.columns)

# %%
data_final.isna().sum()
# Out:
# age                            0
# campaign                       0
# emp.var.rate                   0
# cons.price.idx                 0
# cons.conf.idx                  0
# euribor3m                      0
# nr.employed                    0
# housing                        0
# loan                           0
# month                          0
# day_of_week                    0
# poutcome                       0
# previous_campaign_contacted    0
# job                            0
# marital                        0
# education                      0
# dtype: int64

# %% [markdown]
# The missing values have been treated.

# %% [markdown]
# Building Base Model:

# %%
from sklearn.model_selection import train_test_split

# %%
y=data['y']

# %%
target=pd.get_dummies(y,drop_first=True)
target
# Out:
#        yes
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 40027    1
# 40028    0
# 40029    1
# 40030    1
# 40031    0
#
# [40032 rows x 1 columns]

# %%
target['y']=target['yes']

# %%
X=data_final
y=target['y']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100)

# %%
rfc_model = rfc.fit(X_train,y_train)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y_pred= rfc_model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8903459472961159

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      7107
#            1       0.52      0.26      0.35       900
#
#     accuracy                           0.89      8007
#    macro avg       0.72      0.62      0.64      8007
# weighted avg       0.87      0.89      0.87      8007

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[6893,  214],
#        [ 664,  236]], dtype=int64)

# %%
target['y'].value_counts()
# Out:
# 0    35573
# 1     4459
# Name: y, dtype: int64

# %%
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test,y_pred))
# Out:
# 0.6160555321044979

# %%
from sklearn.metrics import roc_curve
tpr,fpr,threshold=roc_curve(y_test,y_pred)
print(tpr)
print(fpr)
print(threshold)
# Out:
# [0.         0.03011116 1.        ]
# [0.         0.26222222 1.        ]
# [2 1 0]

# %%
plt.plot(tpr,fpr)
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
plt.plot(tpr,fpr)
plt.plot([0,1],[0,1])

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
LR=LogisticRegression()
LR.fit(X_train,y_train)
y_pred=LR.predict(X_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8977144998126639

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.94      7107
#            1       0.66      0.18      0.29       900
#
#     accuracy                           0.90      8007
#    macro avg       0.78      0.59      0.62      8007
# weighted avg       0.88      0.90      0.87      8007

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7023,   84],
#        [ 735,  165]], dtype=int64)

# %%
print(roc_auc_score(y_test,y_pred))
# Out:
# 0.5857570001407063

# %%
tpr,fpr,threshold=roc_curve(y_test,y_pred)
print(tpr)
print(fpr)
print(threshold)
# Out:
# [0.         0.01181933 1.        ]
# [0.         0.18333333 1.        ]
# [2 1 0]

# %%
plt.plot(tpr,fpr)
plt.plot([0,1],[0,1])
